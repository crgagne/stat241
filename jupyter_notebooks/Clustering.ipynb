# %%
import numpy as np
import scipy.stats
from scipy import stats

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib inline

import networkx as nx
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
X.shape
# Out:
# (3, 100)

# %%
#### Using Unit Normalization. 

t = 4
n = 5000
clusters = 4
X = np.zeros((t,n))
u = np.empty((t,n))
l = np.empty((n))
corr = 0.6
e = 0.4
SNR = .6
for ui in range(clusters):
    u[:,ui] =generate_mean_time_series(t,corr,e)

    
for xi in range(n): 
    clust = np.random.randint(clusters)
    x = generate_x_from_mean_single(u[:,clust],t,SNR)
    X[:,xi] = x
    l[xi] = clust

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
cols = ['b','y','r','k']
for c in range(clusters):
    ax.scatter(X[0,l==c],X[1,l==c], X[2,l==c],color=cols[c])

# %%
t = 3
n = 100
clusters = 5
X = np.zeros((t,n))
u = np.empty((t,n))
l = np.empty((n))
corr = 0.6
e = 0.4
SNR = 0.5
for ui in range(clusters):
    u[:,ui] =generate_mean_time_series(t,corr,e,how_to_norm=2)

for xi in range(n): 
    clust = np.random.randint(3)
    x = generate_x_from_mean_single(u[:,clusters],t,SNR,how_to_norm=2)
    X[:,xi] = x
    l[xi] = clust
    
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[0,:],X[1,:], X[2,:])

# %%
t = 3
n = 100
clusters = 5
X = np.zeros((t,n))
u = np.empty((t,n))
l = np.empty((n))
corr = 0.6
e = 0.4
SNR = .5
for ui in range(clusters):
    u[:,ui] =generate_mean_time_series(t,corr,e,how_to_norm=3)

for xi in range(n): 
    clust = np.random.randint(3)
    x = generate_x_from_mean_single(u[:,clusters],t,SNR,how_to_norm=3)
    X[:,xi] = x
    l[xi] = clust
    
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[0,:],X[1,:], X[2,:])
